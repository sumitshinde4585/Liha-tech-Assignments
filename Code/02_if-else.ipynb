# %% [markdown]
# ## Problem Statements : if-else

# %%
a=input("Enter 1st number")
b=input("Enter 2nd number")
c=input("Enter 3rd number")
if a>b and a>c: 
    print(a, "a is grater")
elif b>c:
    print(b, "b is grater")
else:
    print(c, "c is grater")
# Out:
# 23 b is grater

# %%
n=int(input("Enter number: "))
if n%5 == 0 and n%11 == 0:
    print(n, " is divisible by 5 and 11")
else:
    print(n, " is not divisible by 5 and 11")
# Out:
# 44  is not divisible by 5 and 11

# %%
n=int(input("Enter number: "))
if n %2 ==0:
    print(n, "is Even")
else:
    print(n,"is Odd")
# Out:
# 56 is Even

# %%
n=int(input("Enter Year: "))
if n%4==0 and n%100 !=0:
    print(n,"year is leap year")
elif n%100==0 and n%400==0:
    print(n,"year is leap year")
else:
    print(n,"year is not leap year")
# Out:
# 2016 year is leap year

# %%
ch=input("Enter Char")
if ch.isalpha():
    print(ch, "is Alphabet")
else:
    print(ch, "is NOt Alphabet")
# Out:
# a is Alphabet

# %%
ch=input("Enter Char")
if ch.isupper():
    print(ch, "is Uppercase")
else:
    print(ch, "is Lowercase")
# Out:
# A is Uppercase

# %%
amount=int(input("Enter Amount:"))
note=int(input("Enter Note Price:"))
print(f"Total {note}rs note are in {amount}Amount is {amount//note}Notes ")
# Out:
# Total 50rs note are in 1000Amount is 20Notes

# %%
a=int(input("Enter 1st Angle"))
b=int(input("Enter 2nd Angle"))
c=int(input("Enter 3rd Angle"))
if 0<=a>=180 or 0<=b>=180 or 0<=c>=180:
    print("triangle is not valid") 
elif a+b+c ==180:
    print("triangle is valid")
else:
    print("triangle is not valid")
# Out:
# triangle is valid

# %%
a=int(input("Enter 1st side"))
b=int(input("Enter 2nd side"))
c=int(input("Enter 3rd side"))
if a>=b+c or b>=a+c or c>=a+b or a <= 0 or b <= 0 or c <= 0:
    print("triangle is not valid")
else:
    print("triangle is valid")
# Out:
# triangle is valid

# %%
a=int(input("Enter 1st side"))
b=int(input("Enter 2nd side"))
c=int(input("Enter 3rd side"))

if a <= 0 or b <= 0 or c <= 0 or a + b <= c or a + c <= b or b + c <= a:
    print("Not a valid triangle")

elif a == b == c:
    print("Equilateral triangle")

elif a == b or b == c or a == c:
    print("Isosceles triangle")

else:
    print("Scalene triangle")
# Out:
# Equilateral triangle

# %%
Physics =int(input("Enter Physics marks:"))
Chemistry =int(input("Enter Chemistry marks:"))
Biology =int(input("Enter Biology marks:"))
Mathematics =int(input("Enter Mathematics marks:"))
Computer=int(input("Enter Computer marks:"))
Percentage=(Physics+Chemistry+Biology+Mathematics+Computer)/500*100
if Percentage >= 90:
    print("Grade A")
elif Percentage >= 80:
    print("Grade B")
elif Percentage >= 70:
    print("Grade C")
elif Percentage >= 60:
    print("Grade D")
elif Percentage >= 40:
    print("Grade E")
else:
    print("Grade F")
# Out:
# Grade B

# %%
salary = float(input("Enter Basic Salary: "))

if salary <= 10000:
    hra = salary * 20 / 100
    da = salary * 80 / 100

elif salary <= 20000:
    hra = salary * 30 / 100
    da = salary * 90 / 100

else:
    hra = salary * 35 / 100
    da = salary * 95 / 100

gross_salary = salary + hra + da

print("Basic Salary =", salary)
print("HRA =", hra)
print("DA =", da)
print("Gross Salary =", gross_salary)
# Out:
# Basic Salary = 20000.0
# HRA = 6000.0
# DA = 18000.0
# Gross Salary = 44000.0

# %%
unit=int(input("Enter electricity unit use: "))
bill=0
if 0<unit<=50:
    bill=unit*0.50
elif 50<unit<=150:
    bill=50*0.50+(unit-50)*0.75
elif 150<unit<=250:
    bill=50*0.50+100*0.75+(unit-150)*1.25
else:
    bill=50*0.50+100*0.75+100*1.25+(unit-250)*1.50
totalBill=bill*1.17
print("Total Electricity bill of ",unit,"unit is :",round(totalBill,2),"Rs")
# Out:
# Total Electricity bill of  187 unit is : 171.11 Rs
